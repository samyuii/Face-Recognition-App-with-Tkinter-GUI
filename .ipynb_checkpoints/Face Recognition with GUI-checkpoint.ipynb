# %%
from tkinter import Tk, Label, Button, Entry, StringVar, messagebox

import cv2
import numpy as np
import os

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    if len(faces) == 0:
        return None

    for (x, y, w, h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

class FaceRecognitionApp:
    def __init__(self, master):
        self.master = master
        master.title("Face Recognition App")

        self.label = Label(master, text="Enter Your Name:")
        self.label.grid(row=0, column=0, padx=10, pady=10)

        self.name_entry = Entry(master)
        self.name_entry.grid(row=0, column=1, padx=10, pady=10)

        self.collect_button = Button(master, text="Collect Samples", command=self.collect_samples)
        self.collect_button.grid(row=1, column=0, columnspan=2, pady=10)

        self.train_button = Button(master, text="Train Model", command=self.train_model)
        self.train_button.grid(row=2, column=0, columnspan=2, pady=10)

        self.recognize_button = Button(master, text="Recognize Faces", command=self.recognize_faces)
        self.recognize_button.grid(row=3, column=0, columnspan=2, pady=10)

        self.status_var = StringVar()
        self.status_label = Label(master, textvariable=self.status_var, fg="blue")
        self.status_label.grid(row=4, column=0, columnspan=2, pady=10)

    def collect_samples(self):
        name = self.name_entry.get().strip()
        if not name:
            messagebox.showerror("Input Error", "Please enter your name.")
        else:
            self.status_var.set("Collecting samples for " + name + "...")
            collect_face_samples(name)
            self.status_var.set("Samples collected for " + name + ".")

    def train_model(self):
        self.status_var.set("Training the model, please wait...")
        self.model = train_face_recognition()
        self.status_var.set("Model trained successfully!")

    def recognize_faces(self):
        name = self.name_entry.get().strip()
        if not name:
            messagebox.showerror("Input Error", "Please enter your name.")
        else:
            self.status_var.set("Recognizing faces, please wait...")
            recognize_face(self.model, name)
            self.status_var.set("Recognition complete for " + name + ".")
            
def collect_face_samples(name, data_path='D://Projects//Face-Detection-using-OpenCV//image_samples'):
    cap = cv2.VideoCapture(0)
    count = 0

    while True:
        ret, frame = cap.read()
        detected_face = face_extractor(frame)

        if detected_face is not None:
            count += 1
            face = cv2.resize(detected_face, (200, 200))
            face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

            file_name_path = os.path.join(data_path, f'{name}_image{count}.jpg')
            cv2.imwrite(file_name_path, face)

            cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow('Face Cropper', face)
        else:
            print("Face not found")
            pass

        if cv2.waitKey(1) == 13 or count == 100:
            break

    cap.release()
    cv2.destroyAllWindows()
    print("Collecting Samples Complete")

def train_face_recognition(data_path='D://Projects//Face-Detection-using-OpenCV//image_samples'):
    onlyfiles = [f for f in os.listdir(data_path) if os.path.isfile(os.path.join(data_path, f))]

    Training_Data, Labels = [], []

    for i, file in enumerate(onlyfiles):
        image_path = os.path.join(data_path, file)
        print("Loading image:", image_path)
        images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        if images is not None:
            Training_Data.append(np.asarray(images, dtype=np.uint8))
            Labels.append(i)
            print("Image loaded successfully.")
        else:
            print("Error loading image:", image_path)

    print("Number of training images loaded:", len(Training_Data))

    Labels = np.asarray(Labels, dtype=np.int32)
    model = cv2.face.LBPHFaceRecognizer_create() 

    model.train(np.asarray(Training_Data), np.asarray(Labels))
    print("Model trained successfully")

    return model

def recognize_face(model, name):
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()
        image, face = face_detector(frame)

        try:
            face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

            results = model.predict(face)
            print(results)
            if results[1] < 500:
                confidence = int(100 * (1 - (results[1])/400))
                display_string = f'{confidence}% Confident it is {name}'

            cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 120, 150), 2)

            if confidence > 80:
                cv2.putText(image, f'Hey {name}', (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2)
                cv2.imshow('Face Recognition', image )
            else:
                cv2.putText(image, "I don't know", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
                cv2.imshow('Face Recognition', image )

        except Exception as e:
            print(f"Error Recognising Face: {e}")
            cv2.putText(image, "Error Recognising Face", (130, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
            cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
            cv2.imshow('Face Recognition', image )
            pass

        if cv2.waitKey(1) == 13:
            break

    cap.release()
    cv2.destroyAllWindows()

def face_detector(img, size=0.5):
    # Convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if len(faces) == 0:
        return img, []

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 255), 2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
        
    return img, roi 

root = Tk()
app = FaceRecognitionApp(root)
root.mainloop()
# Out:
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image1.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image10.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image100.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image11.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image12.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image13.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image14.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image15.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image16.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image17.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image18.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image19.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image2.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image20.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image21.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image22.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image23.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image24.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image25.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image26.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image27.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image28.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image29.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image3.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image30.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image31.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image32.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image33.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image34.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image35.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image36.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image37.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image38.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image39.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image4.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image40.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image41.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image42.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image43.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image44.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image45.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image46.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image47.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image48.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image49.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image5.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image50.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image51.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image52.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image53.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image54.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image55.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image56.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image57.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image58.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image59.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image6.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image60.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image61.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image62.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image63.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image64.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image65.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image66.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image67.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image68.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image69.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image7.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image70.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image71.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image72.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image73.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image74.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image75.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image76.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image77.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image78.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image79.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image8.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image80.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image81.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image82.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image83.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image84.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image85.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image86.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image87.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image88.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image89.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image9.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image90.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image91.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image92.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image93.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image94.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image95.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image96.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image97.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image98.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak Jain_image99.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image1.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image10.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image100.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image11.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image12.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image13.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image14.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image15.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image16.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image17.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image18.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image19.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image2.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image20.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image21.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image22.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image23.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image24.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image25.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image26.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image27.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image28.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image29.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image3.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image30.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image31.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image32.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image33.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image34.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image35.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image36.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image37.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image38.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image39.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image4.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image40.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image41.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image42.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image43.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image44.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image45.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image46.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image47.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image48.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image49.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image5.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image50.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image51.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image52.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image53.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image54.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image55.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image56.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image57.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image58.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image59.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image6.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image60.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image61.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image62.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image63.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image64.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image65.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image66.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image67.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image68.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image69.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image7.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image70.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image71.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image72.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image73.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image74.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image75.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image76.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image77.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image78.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image79.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image8.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image80.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image81.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image82.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image83.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image84.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image85.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image86.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image87.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image88.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image89.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image9.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image90.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image91.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image92.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image93.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image94.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image95.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image96.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image97.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image98.jpg
# Image loaded successfully.
# Loading image: D://Projects//Face-Detection-using-OpenCV//image_samples\Samyak_image99.jpg
# Image loaded successfully.
# Number of training images loaded: 200
# Model trained successfully
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# (186, 48.53911581773493)
# (186, 53.533394883433154)
# (186, 53.533394883433154)
# (0, 52.40899602473155)
# (0, 52.40899602473155)
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# (186, 53.04389876030065)
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
#
# Error Recognising Face: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
